# %% [markdown]
# #### 1 Problem Understanding
#
# -Analyze pharmaceutical sales
#
# -Identify trends, top drugs, seasonality

# %% [markdown]
# #### 2 import dependencies and load dataset

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load the dataset into my dataframe
path = 'C:\\Users\\kolad\\OneDrive\\Documents\\Data Science Project\\Analysing-pharmaceutical-sales-data\\data\\salesdaily.csv'
df = pd.read_csv(path)

# %%
# Display the first few rows to understand the structure of the dataset
df.head()
# Out:
#       datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06  Year  Month  \
# 0  1/2/2014    0.0   3.67    3.4  32.40   7.0   0.0   0.0  2.0  2014      1
# 1  1/3/2014    8.0   4.00    4.4  50.60  16.0   0.0  20.0  4.0  2014      1
# 2  1/4/2014    2.0   1.00    6.5  61.85  10.0   0.0   9.0  1.0  2014      1
# 3  1/5/2014    4.0   3.00    7.0  41.10   8.0   0.0   3.0  0.0  2014      1
# 4  1/6/2014    5.0   1.00    4.5  21.70  16.0   2.0   6.0  2.0  2014      1
#
#    Hour Weekday Name
# 0   248     Thursday
# 1   276       Friday
# 2   276     Saturday
# 3   276       Sunday
# 4   276       Monday

# %% [markdown]
# #### 3. Data Understanding
#
# shape, info, describe, columns

# %%
df.shape
# Out:
# (2106, 13)

# %%
#data statistics
df.describe().T
# Out:
#         count         mean        std     min      25%      50%       75%  \
# M01AB  2106.0     5.033683   2.737579     0.0     3.00     4.99     6.670
# M01AE  2106.0     3.895830   2.133337     0.0     2.34     3.67     5.138
# N02BA  2106.0     3.880441   2.384010     0.0     2.00     3.50     5.200
# N02BE  2106.0    29.917095  15.590966     0.0    19.00    26.90    38.300
# N05B   2106.0     8.853627   5.605605     0.0     5.00     8.00    12.000
# N05C   2106.0     0.593522   1.092988     0.0     0.00     0.00     1.000
# R03    2106.0     5.512262   6.428736     0.0     1.00     4.00     8.000
# R06    2106.0     2.900198   2.415816     0.0     1.00     2.00     4.000
# Year   2106.0  2016.401235   1.665060  2014.0  2015.00  2016.00  2018.000
# Month  2106.0     6.344255   3.386954     1.0     3.00     6.00     9.000
# Hour   2106.0   275.945869   1.970547   190.0   276.00   276.00   276.000
#
#                max
# M01AB    17.340000
# M01AE    14.463000
# N02BA    16.000000
# N02BE   161.000000
# N05B     54.833333
# N05C      9.000000
# R03      45.000000
# R06      15.000000
# Year   2019.000000
# Month    12.000000
# Hour    276.000000

# %% [markdown]
# The sales daily dataset has 2106 rows and 13 columns

# %%
# datatype and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datum         2106 non-null   object
#  1   M01AB         2106 non-null   float64
#  2   M01AE         2106 non-null   float64
#  3   N02BA         2106 non-null   float64
#  4   N02BE         2106 non-null   float64
#  5   N05B          2106 non-null   float64
#  6   N05C          2106 non-null   float64
#  7   R03           2106 non-null   float64
#  8   R06           2106 non-null   float64
#  9   Year          2106 non-null   int64
#  10  Month         2106 non-null   int64
#  11  Hour          2106 non-null   int64
#  12  Weekday Name  2106 non-null   object
# dtypes: float64(8), int64(3), object(2)
# memory usage: 214.0+ KB

# %% [markdown]
# #### 4. Data Cleaning

# %%
# convert the date column to datetime format
df['datum'] = pd.to_datetime

# %% [markdown]
# #### 5. EDA
# Let's explore the patterns in our data

# %%
df.columns
# Out:
# Index(['datum', 'M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03',
#        'R06', 'Year', 'Month', 'Hour', 'Weekday Name'],
#       dtype='object')

# %%
# Total sales distribution

drug_cols = ['M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03',
       'R06']

df[drug_cols].sum().plot(kind='bar')
plt.title("Total Sales Distribution per Drugs Category")
plt.xlabel("Drugs")
plt.ylabel("Total Sales")

plt.show()

# %% [markdown]
# N02BE has the highest sales among the list of pharmaceuticals medication, followed by N05B
